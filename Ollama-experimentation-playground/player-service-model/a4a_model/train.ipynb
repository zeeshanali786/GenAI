# %%
import pandas as pd

# %%
df = pd.read_csv("player.csv")

# %%
df.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay  ... nameLast       nameGiven  \
# 0      Denver        NaN         NaN       NaN  ...  Aardsma     David Allan
# 1      Mobile        NaN         NaN       NaN  ...    Aaron     Henry Louis
# 2      Mobile     1984.0         8.0      16.0  ...    Aaron      Tommie Lee
# 3      Orange        NaN         NaN       NaN  ...     Aase  Donald William
# 4  Palm Beach        NaN         NaN       NaN  ...     Abad   Fausto Andres
#
#   weight height bats throws       debut   finalGame   retroID    bbrefID
# 0  215.0   75.0    R      R  2004-04-06  2015-08-23  aardd001  aardsda01
# 1  180.0   72.0    R      R  1954-04-13  1976-10-03  aaroh101  aaronha01
# 2  190.0   75.0    R      R  1962-04-10  1971-09-26  aarot101  aaronto01
# 3  190.0   75.0    R      R  1977-07-26  1990-10-03  aased001   aasedo01
# 4  184.0   73.0    L      L  2001-09-10  2006-04-13  abada001   abadan01
#
# [5 rows x 24 columns]

# %%
import numpy as np
from scipy import stats

# %%
df["birthZ"] = stats.zscore(df["birthYear"] + (df["birthMonth"] - 1.0)/12.0 + (df["birthDay"] - 1.0)/30.0, nan_policy="omit")

# %%
df["weightZ"] = stats.zscore(df["weight"], nan_policy="omit")
df["heightZ"] = stats.zscore(df["height"], nan_policy="omit")
df["batsN"] = df["bats"].apply(lambda b: 1.0 if b == 'R' else -1.0 if b == 'L' else 0.0)
df["throwsN"] = df["throws"].apply(lambda b: 1.0 if b == 'R' else -1.0 if b == 'L' else 0.0)

# %%
df[["birthZ", "weightZ", "heightZ"]] = df[["birthZ", "weightZ", "heightZ"]].fillna(0.0)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
features = ["birthZ", "heightZ", "weightZ", "batsN", "throwsN"]
nn_model = NearestNeighbors(n_neighbors=25)
nn_model.fit(df[features])
# Out:
# NearestNeighbors(n_neighbors=25)

# %%
def get_nearest_neighbors(id: str, n=25):
    seed = df[df["playerID"] == id][features]
    neighbor_indices = nn_model.kneighbors(seed, n, return_distance=False)
    return df.take(neighbor_indices[0])["id"]

# %%
df.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay  ...       debut   finalGame  \
# 0      Denver        NaN         NaN       NaN  ...  2004-04-06  2015-08-23
# 1      Mobile        NaN         NaN       NaN  ...  1954-04-13  1976-10-03
# 2      Mobile     1984.0         8.0      16.0  ...  1962-04-10  1971-09-26
# 3      Orange        NaN         NaN       NaN  ...  1977-07-26  1990-10-03
# 4  Palm Beach        NaN         NaN       NaN  ...  2001-09-10  2006-04-13
#
#     retroID    bbrefID birthFraction    birthZ   weightZ   heightZ batsN  \
# 0  aardd001  aardsda01      1.176571  1.176571  1.313516  1.039759   1.0
# 1  aaroh101  aaronha01     -0.004124 -0.004124 -0.304034 -0.111418   1.0
# 2  aarot101  aaronto01      0.129586  0.129586  0.158123  1.039759   1.0
# 3  aased001   aasedo01      0.498705  0.498705  0.158123  1.039759   1.0
# 4  abada001   abadan01      0.948049  0.948049 -0.119171  0.272308  -1.0
#
#   throwsN
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4    -1.0
#
# [5 rows x 30 columns]

# %%
seed = df[df["playerID"] == "aaronha01"][features]
neighbor_indices = nn_model.kneighbors(seed, 25, return_distance=False)

# %%
df.take(neighbor_indices[0])
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 1      aaronha01     1934.0         2.0       5.0          USA         AL
# 11649  mendomi01     1933.0        11.0      16.0         Cuba        NaN
# 4059   davieje01     1933.0         2.0      10.0          USA         MI
# 17204  taussdo01     1932.0         2.0      19.0          USA         NY
# 1504    boakch01     1935.0         6.0      19.0          USA         PA
# 502    asproke01     1931.0         9.0      22.0          USA         NY
# 8975   kaskoed01     1931.0         6.0      27.0          USA         NJ
# 16072  silveal01     1935.0         8.0      26.0          USA         CA
# 15760  segrika01     1931.0         4.0      14.0          USA         TX
# 11527  mcnerje01     1936.0         8.0       7.0          USA         IA
# 10451  luttrly01     1930.0         2.0      22.0          USA         IL
# 3931   dahlkje01     1929.0         6.0       8.0          USA         WI
# 9337   klinebo02     1929.0         1.0      27.0          USA         FL
# 17366  thomabu02     1929.0         3.0      10.0          USA         MO
# 7167   hansedo01     1928.0        12.0      16.0          USA         CA
# 10193  littrja01     1929.0         1.0      22.0          USA         KY
# 11322  mcfaror01     1938.0         6.0      28.0         Cuba        NaN
# 12106  mooreja01     1939.0         2.0      19.0          USA         FL
# 6594   gotayju01     1939.0         6.0       9.0         P.R.        NaN
# 2283   burnewa01     1929.0         6.0      20.0          USA         VA
# 8287   huntebi03     1928.0         6.0       4.0          USA         PA
# 11197  mcclajo01     1933.0         5.0       5.0          USA         TN
# 10052  lewanda01     1928.0         1.0       6.0          USA         NY
# 4029   daughdo01     1927.0        10.0      12.0          USA         PA
# 9071   kellybo01     1927.0        10.0       4.0          USA         OH
#
#             birthCity  deathYear  deathMonth  deathDay  ...       debut  \
# 1              Mobile        NaN         NaN       NaN  ...  1954-04-13
# 11649  Ceiba del Agua        NaN         NaN       NaN  ...  1970-04-09
# 4059          Detroit        NaN         NaN       NaN  ...  1959-04-14
# 17204        New York        NaN         NaN       NaN  ...  1958-04-23
# 1504       New Castle     1983.0        11.0      28.0  ...  1960-09-18
# 502          Brooklyn        NaN         NaN       NaN  ...  1957-09-02
# 8975        Elizabeth        NaN         NaN       NaN  ...  1957-04-18
# 16072       San Diego     2002.0         7.0      24.0  ...  1955-06-12
# 15760      Greenville     2015.0         6.0      26.0  ...  1952-07-16
# 11527           Boone        NaN         NaN       NaN  ...  1964-04-16
# 10451     Bloomington     1984.0         7.0      11.0  ...  1956-05-15
# 3931         Marathon     2006.0         9.0       2.0  ...  1956-05-06
# 9337   St. Petersburg        NaN         NaN       NaN  ...  1955-04-11
# 17366         Sedalia     2015.0         8.0      15.0  ...  1951-09-02
# 7167      Los Angeles     1999.0         9.0      16.0  ...  1951-09-04
# 10193      Louisville     2009.0         6.0       9.0  ...  1952-04-19
# 11322         Oriente     2007.0         7.0      18.0  ...  1962-04-23
# 12106             Jay        NaN         NaN       NaN  ...  1965-04-18
# 6594          Fajardo     2008.0         7.0       4.0  ...  1960-08-06
# 2283           Blairs     2003.0         2.0      12.0  ...  1956-07-15
# 8287     Punxsutawney        NaN         NaN       NaN  ...  1953-04-14
# 11197    Johnson City        NaN         NaN       NaN  ...  1961-04-14
# 10052         Buffalo     1996.0         7.0      19.0  ...  1951-09-22
# 4029            Paris     2015.0         8.0      15.0  ...  1951-04-22
# 9071        Cleveland        NaN         NaN       NaN  ...  1951-05-04
#
#         finalGame   retroID    bbrefID birthFraction    birthZ   weightZ  \
# 1      1976-10-03  aaroh101  aaronha01     -0.004124 -0.004124 -0.304034
# 11649  1970-06-07  mendm103  mendomi01     -0.001288 -0.001288 -0.304034
# 4059   1959-06-09  davij105  davieje01     -0.024383 -0.024383 -0.304034
# 17204  1962-08-11  tausd101  taussdo01     -0.041400 -0.041400 -0.304034
# 1504   1961-05-04  boakc101   boakch01      0.039636  0.039636 -0.304034
# 502    1963-06-21  asprk101  asproke01     -0.049099 -0.049099 -0.304034
# 8975   1966-09-10  kaske101  kaskoed01     -0.051125 -0.051125 -0.304034
# 16072  1956-05-08  silva101  silveal01      0.049360  0.049360 -0.304034
# 15760  1955-09-25  segrk101  segrika01     -0.065711 -0.065711 -0.304034
# 11527  1973-06-15  mcnej101  mcnerje01      0.058274  0.058274 -0.304034
# 10451  1957-05-16  luttl101  luttrly01     -0.087591 -0.087591 -0.304034
# 3931   1956-05-20  dahlj101  dahlkje01     -0.115143 -0.115143 -0.304034
# 9337   1955-09-25  klinb104  klinebo02     -0.109876 -0.109876 -0.350250
# 17366  1951-09-29  thomb103  thomabu02     -0.119600 -0.119600 -0.304034
# 7167   1951-09-11  hansd101  hansedo01     -0.120816 -0.120816 -0.304034
# 10193  1957-09-15  littj104  littrja01     -0.113928 -0.113928 -0.350250
# 11322  1968-08-21  mcfao101  mcfaror01      0.119861  0.119861 -0.304034
# 12106  1965-09-20  moorj102  mooreja01      0.128775  0.128775 -0.304034
# 6594   1969-09-23  gotaj101  gotayju01      0.128775  0.128775 -0.304034
# 2283   1958-06-28  burnw101  burnewa01     -0.105419 -0.105419 -0.396466
# 8287   1958-09-27  huntb105  huntebi03     -0.142695 -0.142695 -0.304034
# 11197  1962-06-01  mcclj104  mcclajo01     -0.022357 -0.022357 -0.165387
# 10052  1951-09-30  lewad102  lewanda01     -0.151204 -0.151204 -0.304034
# 4029   1951-04-22  daugd101  daughdo01     -0.152420 -0.152420 -0.304034
# 9071   1958-06-04  kellb103  kellybo01     -0.158903 -0.158903 -0.304034
#
#         heightZ batsN throwsN
# 1     -0.111418   1.0     1.0
# 11649 -0.111418   1.0     1.0
# 4059  -0.111418   1.0     1.0
# 17204 -0.111418   1.0     1.0
# 1504  -0.111418   1.0     1.0
# 502   -0.111418   1.0     1.0
# 8975  -0.111418   1.0     1.0
# 16072 -0.111418   1.0     1.0
# 15760 -0.111418   1.0     1.0
# 11527 -0.111418   1.0     1.0
# 10451 -0.111418   1.0     1.0
# 3931  -0.111418   1.0     1.0
# 9337  -0.111418   1.0     1.0
# 17366 -0.111418   1.0     1.0
# 7167  -0.111418   1.0     1.0
# 10193 -0.111418   1.0     1.0
# 11322 -0.111418   1.0     1.0
# 12106 -0.111418   1.0     1.0
# 6594  -0.111418   1.0     1.0
# 2283  -0.111418   1.0     1.0
# 8287  -0.111418   1.0     1.0
# 11197 -0.111418   1.0     1.0
# 10052 -0.111418   1.0     1.0
# 4029  -0.111418   1.0     1.0
# 9071  -0.111418   1.0     1.0
#
# [25 rows x 30 columns]

# %%
import joblib

joblib.dump(nn_model, "team_model.joblib")
# Out:
# ['team_model.joblib']

# %%
df.to_csv("features_db.csv", index=False)

# %%
"aardsda01" in list(df["playerID"])
# Out:
# True
